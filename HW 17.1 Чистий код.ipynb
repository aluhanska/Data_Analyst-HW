# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def greet(name):
    print(f"Hello, {name}")


def add(n1, n2):
    return n1 + n2


x = 5
y = 3

display(greet("John"), add(x, y))
# Out:
# Hello, John
# None
# 8

# %% [markdown]
# **Дотримані правила PEP8:**
#
# - додано відступи та перенесення рядків для кращої читабельності;
# - додано 2 порожні рядки між визначеннями функцій;
# - додано пробіли після ком у параметрах функції;
# - додано пробіли навколо бінарного оператора `+`;
# - кожну інструкцію винесено на окремий рядок;
# - покращено форматування змінних `x` та `y`.

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
from math import pi


def calc_area(radius):
    return pi * radius**2


def calc_circumference(radius):
    return 2 * pi * radius


radius = 5

print(
    "Area:", 
    calc_area(radius), 
    "Circumference:", 
    calc_circumference(radius)
)
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %% [markdown]
# **Дотримані правила PEP8:**
#
# - замінено `from math import *` на конкретний імпорт `from math import pi`;
# - назви функцій змінено на `snake_case`;
# - додано 2 порожні рядки між імпортом і функціями;
# - додано 2 порожні рядки між визначеннями функцій;
# - додано пробіли навколо операторів `*`, `=`;
# - додано пробіли після ком у параметрах функцій і викликах;
# - довгий `print()` відформатовано на кілька рядків для кращої читабельності;
# - змінну `r` замінено на більш зрозумілу назву `radius`;
# - кожна інструкція записана з нового рядка.

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal):
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal:
    pass


class Dog(Animal):
    def __init__(self, name):
        self.name = name
        self.type = "Dog"

# %% [markdown]
# **Дотримані правила PEP8:**
#
# - назви класів змінено на `CamelCase` (`Animal`, `Dog`);
# - додано 2 порожні рядки між визначеннями класів;
# - додано пробіли після ком у параметрах методу;
# - додано пробіли навколо оператора `=`;
# - використано подвійні лапки для рядків для єдиного стилю.

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numbers = [1, 2, 3, 4, 5]

for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Дотримані правила PEP8:**
#
# - назву змінної `list` (яка впершу чергу є вбудованим типом Python) перейменовано на більш зрозумілу `numbers`;
# - додано пробіли після ком у списку;
# - кожну інструкцію винесено на окремий рядок;
# - додано правильні відступи в циклі;
# - спрощено цикл відповідно до рекомендацій Python (`for element in iterable`).

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %%
# до
df
# Out:
#    student  math_score  english_score  history_score  average_score
# 0    Alice          89             92             84      88.333333
# 1      Bob          94             88             92      91.333333
# 2  Charlie          77             79             81      79.000000
# 3    David          85             85             89      86.333333

# %%
df['average_score'] = df[
    ['math_score', 'english_score', 'history_score']
].mean(axis=1)

# %%
# після
df
# Out:
#    student  math_score  english_score  history_score  average_score
# 0    Alice          89             92             84      88.333333
# 1      Bob          94             88             92      91.333333
# 2  Charlie          77             79             81      79.000000
# 3    David          85             85             89      86.333333

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

# %%
# переглянемо вихідний вигляд таблиці
df.head()
# Out:
#   product_name product_category  product_price    transaction_date
# 0   elderberry            fruit       4.696674 2000-01-01 00:00:00
# 1        apple            fruit       7.176635 2000-01-01 01:00:00
# 2        dates            fruit       2.507932 2000-01-01 02:00:00
# 3        dates            fruit       2.079303 2000-01-01 03:00:00
# 4        dates            fruit       9.482386 2000-01-01 04:00:00

# %%
# типи колонок наданого набору даних
df.dtypes
# Out:
# product_name                object
# product_category            object
# product_price              float64
# transaction_date    datetime64[ns]
# dtype: object

# %%
# кількість пам'яті, яку займає наданий набір даних
memory_before = df.memory_usage(index=False, deep=True).sum()
memory_before
# Out:
# np.int64(125398392)

# %%
# створимо копію датафрейму та вкажемо назву потрібних стовпців
df_optimized = df.copy()
categorical_columns = [
    'product_name',
    'product_category'
]

# %%
# перетворення стовпців на категоріальний тип  
for col in categorical_columns:
    df_optimized[col] = pd.Categorical(df_optimized[col])

# %%
# типи колонок нового набору даних
df_optimized.dtypes
# Out:
# product_name              category
# product_category          category
# product_price              float64
# transaction_date    datetime64[ns]
# dtype: object

# %%
# кількість пам'яті, яку займає новий набір даних
memory_after = df_optimized.memory_usage(index=False, deep=True).sum()
memory_after
# Out:
# np.int64(18000611)

# %%
memory_reduction = memory_before / memory_after

# %%
print(f"Новий датафрейм займає в {memory_reduction:.2f} рази менше пам'яті.")
# Out:
# Новий датафрейм займає в 6.97 рази менше пам'яті.

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
# 7.1

data_path = '../Data/ecommerce_data.csv'
data = pd.read_csv(
    data_path,
    encoding = 'ISO-8859-1'
)
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
data['CustomerID'].isna().sum()
# Out:
# np.int64(135080)

# %%
data_updated = data.copy()

# %%
# 7.2

data_updated['CustomerID'] = (
    data_updated['CustomerID']
    .fillna(-1)
    .astype(str)
)

data_updated['CustomerID'].isna().sum()
# Out:
# np.int64(0)

# %%
data_updated.shape
# Out:
# (541909, 8)

# %%
data_updated.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID      object
# Country         object
# dtype: object

# %%
# !pip install sweetviz

# %%
import sweetviz as sv

# %%
germany_data = data_updated[
    data_updated['Country'] == 'Germany'
]

france_data = data_updated[
    data_updated['Country'] == 'France'
]

# %%
# 7.3

import warnings

with warnings.catch_warnings(record=True):
    compare_report = sv.compare(
        [germany_data, 'Germany'],
        [france_data, 'France']
    )
    
    compare_report.show_html(
        'germany_vs_france_report.html'
    )
# Out:
#                                              |                                                          | [  0…
# Report germany_vs_france_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# **5 відмінностей на основі побудованого звіту:**
#
# 1) Для Німеччини кількість замовлень 1 виду товару (згідно з унікальними значеннями `InvoiceNo`) більша на 1 %, ніж для Франції (6 % проти 5 %).
# 2) Для Франції середня кількість замовлень 1 товару (AVG `Quantity`) дещо вища: 13 проти 12 для Німеччини.
# 3) В середньому `UnitPrice` для Франції дещо більший: ~5 проти ~4 для Німеччини.
# 4) Значення `UnitPrice` для Франції більш розсіяні та варіативні за рахунок вищих значень стандартного відхилення (STD) та дисперсії (VAR): 79.9 та 6385 проти 16.5 і 274 для Німеччини.
# 5) Обидва розподіли значень `UnitPrice` мають сильну правосторонню асиметрію, але для Франції вона значно сильніша через наявність великих значень: асиметрія (SKEW) становить 2574, що майже в 3 рази більше, ніж для Німеччини (866).

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %%
# фінальна версія коду з чату

def calculate_variance(numbers):
    if not numbers:
        return None

    mean = sum(numbers) / len(numbers)
    mean_squares = sum(number ** 2 for number in numbers) / len(numbers)

    variance = mean_squares - mean ** 2

    return variance


numbers = [75, 80, 85, 90, 95]

result = calculate_variance(numbers)

print(result)
# Out:
# 50.0

# %% [markdown]
# Під час звернення до ChatGPT в основному застосовано промпти наступних концепцій (згідно лекційного матеріалу): **Code Review**, **Error Handling** та **Code Consistency**.
#
# Посилання з промптами та відповідями чата: https://chatgpt.com/share/6a0072e1-f680-83eb-b94a-4b7954f20ebc
#
# Під час виконання цього завдання я зрозуміла, що ChatGPT (безкоштовна версія) треба "змушувати" себе перевіряти :)
